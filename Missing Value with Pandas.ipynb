# %% [markdown]
# # Missing Value with Pandas

# %% [markdown]
# **Objectives:**
#
#
# *   Missing Value
# *   Read this [document](http://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html) for more details

# %% [markdown]
# **Missing Value:**
#
#
# *   What are missing values?
# *   Why need to handle missing values?
# *   How to detect missing values?
# *   How to handle missing values?

# %% [markdown]
# ###Import packages, create(load) dataframe

# %%
import numpy as np # numpy
import pandas as pd # pandas

# %%
# create a dictionary
raw_data = {'name': ['Jason', np.nan, 'Mike', 'Rayman', 'Alex', 'Meimei'], 
        'age': [36, np.nan, 36, 18, 36, 16], 
        'gender': ['m', np.nan, 'm', np.nan, 'f', 'f'], 
        'preMLScore': [1, np.nan, np.nan, 2, 3, 90],
        'postMLScore': [65, np.nan, np.nan, 62, 70, 100]}

# create a dataframe by passing a dictionary
df = pd.DataFrame(raw_data, columns = ['name', 'age', 'gender', 'preMLScore', 'postMLScore'])

# %%
df
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1     NaN   NaN    NaN         NaN          NaN
# 2    Mike  36.0      m         NaN          NaN
# 3  Rayman  18.0    NaN         2.0         62.0
# 4    Alex  36.0      f         3.0         70.0
# 5  Meimei  16.0      f        90.0        100.0

# %%
#@title (Optional) Package pandas_profiling
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>20.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>320.0 B </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>53.3 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_age"><code>age</code></a> has 1 / 16.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_gender"><code>gender</code></a> has 2 / 33.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_name"><code>name</code></a> has 1 / 16.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_postMLScore"><code>postMLScore</code></a> is highly correlated with <a href="#pp_var_preMLScore"><code>preMLScore</code></a> (ρ = 0.98402) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_preMLScore"><code>preMLScore</code></a> has 2 / 33.3% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_age">age<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>

# %% [markdown]
# ### Detect missing values

# %%
df.info() # the overview information for the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
# name           5 non-null object
# age            5 non-null float64
# gender         4 non-null object
# preMLScore     4 non-null float64
# postMLScore    4 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe() # basic stats
# Out:
#              age  preMLScore  postMLScore
# count   5.000000    4.000000     4.000000
# mean   28.400000   24.000000    74.250000
# std    10.430724   44.007575    17.480942
# min    16.000000    1.000000    62.000000
# 25%    18.000000    1.750000    64.250000
# 50%    36.000000    2.500000    67.500000
# 75%    36.000000   24.750000    77.500000
# max    36.000000   90.000000   100.000000

# %%
df.isnull().sum() # the number of rows with NaN for each column
# Out:
# name           1
# age            1
# gender         2
# preMLScore     2
# postMLScore    2
# dtype: int64

# %%
df.notnull().sum() # the number of rows without NaN for each column
# Out:
# name           5
# age            5
# gender         4
# preMLScore     4
# postMLScore    4
# dtype: int64

# %%
df.isnull().any(axis=1) # check if there is a NaN in a row
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
df.isnull().any(axis=0) # check if there is a NaN in a column
# Out:
# name           True
# age            True
# gender         True
# preMLScore     True
# postMLScore    True
# dtype: bool

# %% [markdown]
# ###Handle Missing Values

# %% [markdown]
# **Elimination**

# %%
df.dropna() # drop the rows with any NaN, equal to df.dropna(axis=0, how='any')
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 4    Alex  36.0      f         3.0         70.0
# 5  Meimei  16.0      f        90.0        100.0

# %%
df.dropna(how='all', inplace=True) # drop the rows that every column is NaN
df = df.reset_index(drop=True)
df
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1    Mike  36.0      m         NaN          NaN
# 2  Rayman  18.0    NaN         2.0         62.0
# 3    Alex  36.0      f         3.0         70.0
# 4  Meimei  16.0      f        90.0        100.0

# %%
df['playgames'] = np.nan # add an address column that all the values are NaN
df
# Out:
#      name   age gender  preMLScore  postMLScore  playgames
# 0   Jason  36.0      m         1.0         65.0        NaN
# 1    Mike  36.0      m         NaN          NaN        NaN
# 2  Rayman  18.0    NaN         2.0         62.0        NaN
# 3    Alex  36.0      f         3.0         70.0        NaN
# 4  Meimei  16.0      f        90.0        100.0        NaN

# %%
df.dropna(axis=1, how='all') # drop the column that all values are NaN
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1    Mike  36.0      m         NaN          NaN
# 2  Rayman  18.0    NaN         2.0         62.0
# 3    Alex  36.0      f         3.0         70.0
# 4  Meimei  16.0      f        90.0        100.0

# %%
df.dropna(thresh=5) # drop the rows without at least five actual value columns
# Out:
#      name   age gender  preMLScore  postMLScore  playgames
# 0   Jason  36.0      m         1.0         65.0        NaN
# 3    Alex  36.0      f         3.0         70.0        NaN
# 4  Meimei  16.0      f        90.0        100.0        NaN

# %% [markdown]
# **Imputation**

# %%
df.fillna(0) # fill 0 to all missing values
# Out:
#      name   age gender  preMLScore  postMLScore  playgames
# 0   Jason  36.0      m         1.0         65.0        0.0
# 1    Mike  36.0      m         0.0          0.0        0.0
# 2  Rayman  18.0      0         2.0         62.0        0.0
# 3    Alex  36.0      f         3.0         70.0        0.0
# 4  Meimei  16.0      f        90.0        100.0        0.0

# %%
df.gender.fillna(method='ffill') # carry the forward value to the missing value
# Out:
# 0    m
# 1    m
# 2    m
# 3    f
# 4    f
# Name: gender, dtype: object

# %%
df.gender.fillna(method='bfill') # carry the backward value to the missing value
# Out:
# 0    m
# 1    m
# 2    f
# 3    f
# 4    f
# Name: gender, dtype: object

# %%
df["preMLScore"].fillna(df["preMLScore"].median(), inplace=True) # fill preMLScore with its mean
df
# Out:
#      name   age gender  preMLScore  postMLScore  playgames
# 0   Jason  36.0      m         1.0         65.0        NaN
# 1    Mike  36.0      m         2.5          NaN        NaN
# 2  Rayman  18.0    NaN         2.0         62.0        NaN
# 3    Alex  36.0      f         3.0         70.0        NaN
# 4  Meimei  16.0      f        90.0        100.0        NaN

# %% [markdown]
# read [document](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) for group by

# %%
df["postMLScore"].fillna(df.groupby("gender")["postMLScore"].transform("mean"), inplace=True) # fill postMLScore by sex group mean
df
# Out:
#      name   age gender  preMLScore  postMLScore  playgames
# 0   Jason  36.0      m         1.0         65.0        NaN
# 1    Mike  36.0      m         2.5         65.0        NaN
# 2  Rayman  18.0    NaN         2.0         62.0        NaN
# 3    Alex  36.0      f         3.0         70.0        NaN
# 4  Meimei  16.0      f        90.0        100.0        NaN

# %% [markdown]
# ### (Optional)KNN for imputation

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# fake some data for further steps
df['playgames'] = pd.Series([1,1,1,1,0])
y = df['playgames']

# %%
# construct X matrix
X = df[['name', 'age', 'gender', 'preMLScore', 'postMLScore']]
X
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1    Mike  36.0      m         2.5         65.0
# 2  Rayman  18.0    NaN         2.0         62.0
# 3    Alex  36.0      f         3.0         70.0
# 4  Meimei  16.0      f        90.0        100.0

# %%
# select the rows with missing values as testing data
idx_with_nan = X.isnull().any(axis=1)
X_with_nan = X[idx_with_nan]
X_with_nan
# Out:
#      name   age gender  preMLScore  postMLScore
# 2  Rayman  18.0    NaN         2.0         62.0

# %%
# select the rows without missing values as training data
X_no_nan = X[-idx_with_nan]
X_no_nan
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1    Mike  36.0      m         2.5         65.0
# 3    Alex  36.0      f         3.0         70.0
# 4  Meimei  16.0      f        90.0        100.0

# %%
# drop name column, set gender as target variable and train the model, 
clf = KNeighborsClassifier(3, weights='distance')
clf.fit(X_no_nan[['age', 'preMLScore', 'postMLScore']], X_no_nan['gender'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='distance')

# %%
# P
x_imputed = clf.predict(X_with_nan[['age', 'preMLScore', 'postMLScore']])
X_with_imputed = X.copy()
X_with_imputed.loc[idx_with_nan,'gender'] = x_imputed.reshape(-1, 1)
X_with_imputed
# Out:
#      name   age gender  preMLScore  postMLScore
# 0   Jason  36.0      m         1.0         65.0
# 1    Mike  36.0      m         2.5         65.0
# 2  Rayman  18.0      m         2.0         62.0
# 3    Alex  36.0      f         3.0         70.0
# 4  Meimei  16.0      f        90.0        100.0
